# %%
from llm_generator import *

# %%
MODEL_PATH = Path('../results/QuatE/trained_model.pkl')
TRIPLES_PATH = Path('../data/triples_new_without_ct_ss.csv')
RECIPE_PATH_CSV = Path("../data/dataFullLargerRegionAndCountryWithServingsBin.csv")

# %%
user_criteria = {
"meal_type": ["breakfast"]
}

# %%
prompt = generate_recipe_llm(user_criteria, MODEL_PATH, TRIPLES_PATH, RECIPE_PATH_CSV)
# Out:
# ---- Prompt Sent to Gemini LLM ----
#
# You are a world-class culinary expert and innovative chef known for your exceptionally creative dishes.
# Your task is to generate a completely new recipe that meets the following criteria:
#
# User Criteria:
#   - Cooking Method(s): Any
#   - Cuisine Region: Any
#   - Diet Types: Any
#   - Meal Types: breakfast
#   - Cooking Time: Any time
#   - Servings: Any servings
#   - Ingredients: None specified
#   - Health Types: Any
#
# Use the following example recipes for inspiration:
# Example Recipe 1:
# Name: Stand N' Stuff Breakfast Taco
# Description: Make and share this Stand N' Stuff Breakfast Taco  .
# RecipeCategory: Breakfast
# Keywords: Mexican, < 30 Mins, Easy
# RecipeInstructions: 1-) In large bowl
# 2-) beat eggs with whisk. Add half-and-half and salt; beat well. In 10-inch nonstick skillet
# 3-) melt butter over medium heat. Add egg mixture; cook about 7 minutes
# 4-) scraping cooked eggs up from bottom of skillet occasionally
# ...
